# %% [markdown]
# # **Weather Analysis - Task 1**
# ### Suven Consultants and Technologies Pvt Ltd

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore') 
# %matplotlib inline

# %%
df = pd.read_csv('weatherHistory.csv')
df.head()
# Out:
#                   Formatted Date  ...                      Daily Summary
# 0  2006-04-01 00:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 1  2006-04-01 01:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 2  2006-04-01 02:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 3  2006-04-01 03:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 4  2006-04-01 04:00:00.000 +0200  ...  Partly cloudy throughout the day.
#
# [5 rows x 11 columns]

# %%
df.shape
# Out:
# (96453, 11)

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %% [markdown]
# **Now lets change Data type of column df['Formatted Date'] (object) to (datetime)**

# %%
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'],utc= True)
df['Formatted Date']
# Out:
# 0       2006-03-31 22:00:00+00:00
# 1       2006-03-31 23:00:00+00:00
# 2       2006-04-01 00:00:00+00:00
# 3       2006-04-01 01:00:00+00:00
# 4       2006-04-01 02:00:00+00:00
#                    ...
# 96448   2016-09-09 17:00:00+00:00
# 96449   2016-09-09 18:00:00+00:00
# 96450   2016-09-09 19:00:00+00:00
# 96451   2016-09-09 20:00:00+00:00
# 96452   2016-09-09 21:00:00+00:00
# Name: Formatted Date, Length: 96453, dtype: datetime64[ns, UTC]

# %% [markdown]
# ### We will check if there is any Null value in the data

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
# First we set Formatted Date as our index, because we need every year data of a specific month. 
df = df.set_index('Formatted Date')
df.head()
# Out:
#                                  Summary  ...                      Daily Summary
# Formatted Date                            ...
# 2006-03-31 22:00:00+00:00  Partly Cloudy  ...  Partly cloudy throughout the day.
# 2006-03-31 23:00:00+00:00  Partly Cloudy  ...  Partly cloudy throughout the day.
# 2006-04-01 00:00:00+00:00  Mostly Cloudy  ...  Partly cloudy throughout the day.
# 2006-04-01 01:00:00+00:00  Partly Cloudy  ...  Partly cloudy throughout the day.
# 2006-04-01 02:00:00+00:00  Mostly Cloudy  ...  Partly cloudy throughout the day.
#
# [5 rows x 10 columns]

# %% [markdown]
# ### **We only need 3 columns for our task which is ['Formatted Date','Apperent Temperature(c)','Humidity']**
#
# **We need to find Avg Apparent temperature & Avg humidity of specific month from 2006 - 2016.**

# %%
# We need only 2 columns from our Dataset. so will fetch that columns only. 
cols = df[['Apparent Temperature (C)','Humidity']] 
df_avg = cols.resample('MS').mean()
# We are actually displaying the avg apparent temperature (C) and humidity using mean()
df_avg.head()
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625

# %%
# We will plot both value with respect to datetime i.e. index column to check variation in data. 
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time")
sns.lineplot(data=df_avg);

# %% [markdown]
# ### **Conclusion:-**
#
# For 10 years, Average Apparent Temperature change by month-month in that specific year only and remain almost same for every year till 2016.
# The nature of the graph is zig-zag.
#
# there is no change in Average humidity, i.e. straight line parallel to X-axis. That means for 10 years the humidity is approximately constant.

# %% [markdown]
# ## **Now we will do analysis for each month from 2006-2016**

# %%
jan=df_avg[df_avg.index.month ==1]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for JANUARY from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=jan);

# %%
feb=df_avg[df_avg.index.month ==2]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for FEBRUARY from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=feb);

# %%
mar=df_avg[df_avg.index.month ==3]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for MARCH from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=mar);

# %%
apr=df_avg[df_avg.index.month ==4]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for APRIL from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=apr);

# %%
may=df_avg[df_avg.index.month ==5]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for MAY from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=may);

# %%
jun=df_avg[df_avg.index.month ==6]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for JUNE from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=jun);

# %%
jul=df_avg[df_avg.index.month ==7]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for JULY from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=jul);

# %%
aug=df_avg[df_avg.index.month ==8]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for AUGUST from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=aug);

# %%
sep=df_avg[df_avg.index.month ==9]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for SEPTEMBER from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=sep);

# %%
oct=df_avg[df_avg.index.month ==10]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for OCTOBER from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=oct);

# %%
nov=df_avg[df_avg.index.month ==11]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for NOVEMBER from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=nov);

# %%
dec=df_avg[df_avg.index.month ==12]
plt.figure(figsize=(12,7))
plt.title("Changes in Apparent Temperature (C) and Humidity with time for DECEMBER from 2006-2016")
plt.xlabel("Years")
sns.lineplot(data=dec);

# %% [markdown]
# ## **Final Conclusion : -**
#
# 1.)  Average Apparent Temperature (c) increase for year 2008-09 and then again decrease from 2009-10 to its average level. Then slighlty increase for period 2010-11 and then drop again for year 2011-12. For year 2014-15 it decrease drastically and then come to average level for year 2015-16.
#
# 2.) It observed, for year 2009 the Apparent Temperature is at Highest 14.26(C) and for year 2015 the Apparent Temperature is at lowest 10.63(C).
#
# 3.) There is no any change in average Humidity for given year 2006-2016. The humidity graph line is approximately parallel to the X-axis.
